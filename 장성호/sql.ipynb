# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine, text

damage = pd.read_csv('damage.csv', encoding='utf-8')
Electricity_production_unit_price = pd.read_csv('Electricity_production_unit_price.csv', encoding='utf-8')
sales_price = pd.read_csv('sales_price.csv', encoding='utf-8')
sales_revenue_by_use = pd.read_csv('sales_revenue_by_use.csv', encoding='utf-8')
power_generation_cost = pd.read_csv('power_generation_cost.csv', encoding='utf-8')
region = pd.read_csv('region.csv', encoding='utf-8')

# %%
protocol ="mysql+pymysql://"
user = "root"
password = "0000"
host = "localhost"
port = "3306"
db = "comma"
con_str = f"{protocol}{user}:{password}@{host}:{port}/{db}" 
conn = create_engine(con_str)

# %%
sql_stmt = """
CREATE TABLE `Electricity_production_unit_price` (
	`기간`	year not null PRIMARY KEY, 
	`원자력`	int	NULL,
	`유연탄`	int	NULL,
	`무연탄`	int	NULL,
	`유류`	int	NULL,
	`LNG`	int	NULL,
	`양수`	int	NULL,
	`연료전지`	int	NULL,
	`석탄가스화`	int	NULL,
	`태양`	int	NULL,
	`풍력`	int	NULL,
	`수력`	int	NULL,
	`해양`	int	NULL,
	`바이오`	int	NULL,
	`폐기물`	int	NULL,
	`기타`	int	NULL,
	`전기생산단가평균`	int	NOT NULL
);
"""
conn.execute(sql_stmt)

# %%
sql_stmt = """
CREATE TABLE `sales_revenue_by_use` (
	`기간`	year NOT NULL PRIMARY KEY,
	`주택용`	BIGint	NULL,
	`일반용`	BIGint	NULL,
    `교육용`	BIGint	NULL,
	`산업용`	BIGint	NULL,
	`농사용`	BIGint	NULL,
	`가로등`	BIGint	NULL,
	`심야용`	BIGint	NULL,
	`전기판매수입` BIGint	NOT NULL
);

"""
conn.execute(sql_stmt)

# %%
sql_stmt = """
CREATE TABLE `region` (
	`기간`	year	NOT NULL PRIMARY KEY,
	`서울`	int	NULL,
	`부산`	int	NULL,
	`대구`	int	NULL,
	`인천`	int	NULL,
	`광주`	int	NULL,
	`대전`	int	NULL,
	`울산`	int	NULL,
	`세종`	int	NULL,
	`경기`	int	NULL,
	`강원`	int	NULL,
	`충북`	int	NULL,
	`충남`	int	NULL,
	`전북`	int	NULL,
	`전남`	int	NULL,
	`경북`	int	NULL,
	`경남`	int	NULL,
	`제주`	int	NULL,
	`발전량합계`	int	NOT NULL
);
"""
conn.execute(sql_stmt)

# %%
sql_stmt = """
CREATE TABLE `sales_price` (
	`기간`	year	not NULL primary key,
	`평균금액`	int	NOT NULL
);

"""
conn.execute(sql_stmt)

# %%
sql_stmt = """
CREATE TABLE Damage (
    `기간` year NOT NULL ,
	`손해금액` BIGINT NULL,		
    `IND`	INT not null PRIMARY KEY
);

"""
conn.execute(sql_stmt)

# %%
sql_stmt = """
CREATE TABLE `power_generation_cost` (
	`기간` YEAR	NOT NULL,
	`발전비용` BIGINT NULL,
	`IND`	INT not null PRIMARY KEY	
);

"""
conn.execute(sql_stmt)

# %%
damage.to_dict('records')
# Out:
# [{'기간': 2018, '손해금액': 5859219190420, 'index': 1},
#  {'기간': 2019, '손해금액': 6445733474345, 'index': 2},
#  {'기간': 2020, '손해금액': 11745443890000, 'index': 3},
#  {'기간': 2021, '손해금액': 2874394138325, 'index': 4}]

# %%
damage.dtypes
# Out:
# 기간       int64
# 손해금액     int64
# index    int64
# dtype: object

# %%
sql = """
insert into Damage(
기간,
손해금액,
IND
) values(
:기간,
:손해금액,
:ind
)
"""
for param in damage.to_dict('records'):
    conn.execute(text(sql),param)

# %%
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:558, in Connection.query(self, sql, unbuffered)
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:822, in Connection._read_query_result(self, unbuffered)
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1200, in MySQLResult.read(self)
#    1199 try:
# -> 1200     first_packet = self.connection._read_packet()
#    1202     if first_packet.is_ok_packet():
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:772, in Connection._read_packet(self, packet_type)
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1054, "Unknown column '석탄가스화' in 'field list'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[145], line 38
#       1 sql = """
#       2 insert into Electricity_production_unit_price(
#       3 기간,
#    (...)
#      35 :전기생산단가평균)
#      36 """
#      37 for param in Electricity_production_unit_price.to_dict('records'):
# ---> 38     conn.execute(text(sql),param)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\util\deprecations.py:402, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     400 if not skip_warning:
#     401     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 402 return fn(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3176, in Engine.execute(self, statement, *multiparams, **params)
#    3158 """Executes the given construct and returns a
#    3159 :class:`_engine.CursorResult`.
#    3160
#    (...)
#    3173
#    3174 """
#    3175 connection = self.connect(close_with_result=True)
# -> 3176 return connection.execute(statement, *multiparams, **params)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1306, in Connection.execute(self, statement, *multiparams, **params)
#    1302     util.raise_(
#    1303         exc.ObjectNotExecutableError(statement), replace_context=err
#    1304     )
#    1305 else:
# -> 1306     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\elements.py:332, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     328 def _execute_on_connection(
#     329     self, connection, multiparams, params, execution_options, _force=False
#     330 ):
#     331     if _force or self.supports_execution:
# --> 332         return connection._execute_clauseelement(
#     333             self, multiparams, params, execution_options
#     334         )
#     335     else:
#     336         raise exc.ObjectNotExecutableError(self)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1498, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1486 compiled_cache = execution_options.get(
#    1487     "compiled_cache", self.engine._compiled_cache
#    1488 )
#    1490 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1491     dialect=dialect,
#    1492     compiled_cache=compiled_cache,
#    (...)
#    1496     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1497 )
# -> 1498 ret = self._execute_context(
#    1499     dialect,
#    1500     dialect.execution_ctx_cls._init_compiled,
#    1501     compiled_sql,
#    1502     distilled_params,
#    1503     execution_options,
#    1504     compiled_sql,
#    1505     distilled_params,
#    1506     elem,
#    1507     extracted_params,
#    1508     cache_hit=cache_hit,
#    1509 )
#    1510 if has_events:
#    1511     self.dispatch.after_execute(
#    1512         self,
#    1513         elem,
#    (...)
#    1517         ret,
#    1518     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\util\compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:558, in Connection.query(self, sql, unbuffered)
#     556     sql = sql.encode(self.encoding, "surrogateescape")
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:822, in Connection._read_query_result(self, unbuffered)
#     820 else:
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#     824 if result.server_status is not None:
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1200, in MySQLResult.read(self)
#    1198 def read(self):
#    1199     try:
# -> 1200         first_packet = self.connection._read_packet()
#    1202         if first_packet.is_ok_packet():
#    1203             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:772, in Connection._read_packet(self, packet_type)
#     770     if self._result is not None and self._result.unbuffered_active is True:
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1054, "Unknown column '석탄가스화' in 'field list'")
# [SQL:
# insert into Electricity_production_unit_price(
# 기간,
# 유연탄,
# 무연탄,
# 유류,
# LNG,
# 양수,
# 연료전지,
# 석탄가스화,
# 태양,
# 풍력,
# 수력,
# 해양,
# 바이오,
# 폐기물,
# 기타,
# 전기생산단가평균
# ) values(
# %(기간)s,
# %(유연탄)s,
# %(무연탄)s,
# %(유류)s,
# %(LNG)s,
# %(양수)s,
# %(연료전지)s,
# %(석탄가스화)s,
# %(태양)s,
# %(풍력)s,
# %(수력)s,
# %(해양)s,
# %(바이오)s,
# %(폐기물)s,
# %(기타)s,
# %(전기생산단가평균)s)
# ]
# [parameters: {'기간': 2023, '유연탄': 153, '무연탄': 176, '유류': 343, 'LNG': 229, '양수': 246, '연료전지': 159, '석탄가스화': 162.0, '태양': 166, '풍력': 164, '수력': 171, '해양': 156, '바이오': 209, '폐기물': 0, '기타': 177.0, '전기생산단가평균': 145}]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
Electricity_production_unit_price
# Out:
#       기간  원자력  유연탄  무연탄   유류  LNG   양수  연료전지  석탄가스화   태양   풍력   수력   해양  바이오  \
# 0   2023   48  153  176  343  229  246   159  162.0  166  164  171  156  209
# 1   2022   52  157  202  310  239  278   184  192.0  191  191  207  185  230
# 2   2021   56   99  101  217  122  140    94   94.0   93   99  104   93  137
# 3   2020   60   82   81  193   99  113    66   68.0   70   73   79   67  113
# 4   2019   58   86  102  231  119  121    89   82.0   94  103  104   89  120
# 5   2018   62   82  105  179  121  125    94   95.0   98  106  107   93   94
# 6   2017   61   78   95  165  112  108    80   80.0   84   91   94   80   80
# 7   2016   68   74   89  109   99  106    76   76.0   77   83   84   76   76
# 8   2015   63   71  108  150  126  133   116   98.0  169  109  113   99  103
# 9   2014   55   65   91  221  161  172   158    NaN  221  153  156  138  160
# 10  2013   39   59   92  222  161  204   156    NaN  172  163  168  147  153
# 11  2012   40   66  104  253  168  214   157    NaN  171  175  178  155  158
# 12  2011   39   67   99  226  142  169   124    NaN  131  143  135  134  124
# 13  2010   40   61  110  185  128  203   114    NaN  125  124  133  118  115
# 14  2009   36   60  109  147  130  150   102    NaN  104  108  109  120  104
# 15  2008   39   51  118  194  144  197   147    NaN  137  127  134    0  121
# 16  2007   39   41   65  118  105  163    82    NaN   87   84   94    0   84
# 17  2006   38   38   55  117  103  137    85    NaN   82   79   84    0   79
# 18  2005   39   44   54   93   87  108     0    NaN   63   63   71    0   60
# 19  2004   40   42   52   82   78  108     0    NaN   59   56   62    0   55
# 20  2003   43   43   53   84   90   90     0    NaN    0  141   79    0  121
# 21  2002   40   42   49   71   76   84     0    NaN    0   49   55    0   46
# 22  2001   40   41   57   73   88   74     0    NaN    0   50   58    0   54
#
#     폐기물        기타  전기생산단가평균
# 0     0     177.0       145
# 1     0     206.0       153
# 2     0     109.0        95
# 3     0      78.0        80
# 4    95      98.0        89
# 5    97      98.0        90
# 6    96      90.0        83
# 7    96      87.0        80
# 8    98      92.0        84
# 9   104       NaN        90
# 10   87  386087.0        88
# 11   80    1624.0        90
# 12   79     997.0        80
# 13   67    1109.0        73
# 14    7    1361.0        66
# 15    5    1436.0        68
# 16    3   13948.0        57
# 17    2       NaN        53
# 18    1       NaN        51
# 19    0       NaN        49
# 20    8       NaN        52
# 21    0       NaN        47
# 22    0       NaN        48

# %%
sql = """
insert into power_generation_cost(
기간,
발전비용,
IND
) values(
:기간,
:발전비용,
:ind
)
"""
for param in power_generation_cost.to_dict('records'):
    conn.execute(text(sql),param)

# %%
sql = """
insert into region(
기간,
서울,
부산,
대구,
인천,
광주,
대전,
울산,
세종,
경기,
강원,
충북,
충남,
전북,
전남,
경북,
경남,
제주,
발전량합계
) values(
:기간,
:서울,
:부산,
:대구,
:인천,
:광주,
:대전,
:울산,
:세종,
:경기,
:강원,
:충북,
:충남,
:전북,
:전남,
:경북,
:경남,
:제주,
:발전량합계
)
"""
for param in region.to_dict('records'):
    conn.execute(text(sql),param)

# %%
sql = """
insert into sales_price(
기간,
평균금액
) values(
:기간,
:평균금액
)
"""
for param in sales_price.to_dict('records'):
    conn.execute(text(sql),param)

# %%
sql = """
insert into sales_revenue_by_use(
기간,
주택용,
일반용,
교육용,
산업용,
농사용,
가로등,
심야용,
전기판매수입
) values(
:기간,
:주택용,
:일반용,
:교육용,
:산업용,
:농사용,
:가로등,
:심야용,
:전기판매수입
)
"""
for param in sales_revenue_by_use.to_dict('records'):
    conn.execute(text(sql),param)

# %%
Electricity_production_unit_price
# Out:
#       기간  원자력  유연탄  무연탄   유류  LNG   양수  연료전지  석탄가스화   태양   풍력   수력   해양  바이오  \
# 0   2023   48  153  176  343  229  246   159  162.0  166  164  171  156  209
# 1   2022   52  157  202  310  239  278   184  192.0  191  191  207  185  230
# 2   2021   56   99  101  217  122  140    94   94.0   93   99  104   93  137
# 3   2020   60   82   81  193   99  113    66   68.0   70   73   79   67  113
# 4   2019   58   86  102  231  119  121    89   82.0   94  103  104   89  120
# 5   2018   62   82  105  179  121  125    94   95.0   98  106  107   93   94
# 6   2017   61   78   95  165  112  108    80   80.0   84   91   94   80   80
# 7   2016   68   74   89  109   99  106    76   76.0   77   83   84   76   76
# 8   2015   63   71  108  150  126  133   116   98.0  169  109  113   99  103
# 9   2014   55   65   91  221  161  172   158    NaN  221  153  156  138  160
# 10  2013   39   59   92  222  161  204   156    NaN  172  163  168  147  153
# 11  2012   40   66  104  253  168  214   157    NaN  171  175  178  155  158
# 12  2011   39   67   99  226  142  169   124    NaN  131  143  135  134  124
# 13  2010   40   61  110  185  128  203   114    NaN  125  124  133  118  115
# 14  2009   36   60  109  147  130  150   102    NaN  104  108  109  120  104
# 15  2008   39   51  118  194  144  197   147    NaN  137  127  134    0  121
# 16  2007   39   41   65  118  105  163    82    NaN   87   84   94    0   84
# 17  2006   38   38   55  117  103  137    85    NaN   82   79   84    0   79
# 18  2005   39   44   54   93   87  108     0    NaN   63   63   71    0   60
# 19  2004   40   42   52   82   78  108     0    NaN   59   56   62    0   55
# 20  2003   43   43   53   84   90   90     0    NaN    0  141   79    0  121
# 21  2002   40   42   49   71   76   84     0    NaN    0   49   55    0   46
# 22  2001   40   41   57   73   88   74     0    NaN    0   50   58    0   54
#
#     폐기물        기타  전기생산단가평균
# 0     0     177.0       145
# 1     0     206.0       153
# 2     0     109.0        95
# 3     0      78.0        80
# 4    95      98.0        89
# 5    97      98.0        90
# 6    96      90.0        83
# 7    96      87.0        80
# 8    98      92.0        84
# 9   104       NaN        90
# 10   87  386087.0        88
# 11   80    1624.0        90
# 12   79     997.0        80
# 13   67    1109.0        73
# 14    7    1361.0        66
# 15    5    1436.0        68
# 16    3   13948.0        57
# 17    2       NaN        53
# 18    1       NaN        51
# 19    0       NaN        49
# 20    8       NaN        52
# 21    0       NaN        47
# 22    0       NaN        48

# %%
sql = """
insert into Electricity_production_unit_price(
기간,
유연탄,
무연탄,
유류,
LNG,
양수,
연료전지,
석탄가스화,
태양,
풍력,
수력,
해양,
바이오,
폐기물,
기타,
전기생산단가평균
) values(
:기간,
:유연탄,
:무연탄,
:유류,
:LNG,
:양수,
:연료전지,
:석탄가스화,
:태양,
:풍력,
:수력,
:해양,
:바이오,
:폐기물,
:기타,
:전기생산단가평균)
"""
for param in Electricity_production_unit_price.to_dict('records'):
    conn.execute(text(sql),param)

# %%
CONSTRAINT `키 이름` FOREIGN KEY (`키로 들어갈 칼럼`) REFERENCES `프라이머리 키 있는 테이블 이름` (`앞에 테이블에서 쓸 컬럼`)

# %%
sql = """
ALTER TABLE `Damage` ADD CONSTRAINT `FK_damage_year` FOREIGN KEY (`기간`) REFERENCES Electricity_production_unit_price (`기간`);
"""
conn.execute(sql)

# %%
sql = """
ALTER TABLE `power_generation_cost` ADD CONSTRAINT `FK_power_generation_cost_year` FOREIGN KEY (`기간`) REFERENCES Electricity_production_unit_price (`기간`);
"""
conn.execute(sql)

# %%
sql = """
ALTER TABLE `region` ADD CONSTRAINT `FK_region_year` FOREIGN KEY (`기간`) REFERENCES Electricity_production_unit_price (`기간`);
"""
conn.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:558, in Connection.query(self, sql, unbuffered)
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:822, in Connection._read_query_result(self, unbuffered)
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1200, in MySQLResult.read(self)
#    1199 try:
# -> 1200     first_packet = self.connection._read_packet()
#    1202     if first_packet.is_ok_packet():
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:772, in Connection._read_packet(self, packet_type)
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1826, "Duplicate foreign key constraint name 'FK_region_year'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[180], line 4
#       1 sql = """
#       2 ALTER TABLE `region` ADD CONSTRAINT `FK_region_year` FOREIGN KEY (`기간`) REFERENCES Electricity_production_unit_price (`기간`);
#       3 """
# ----> 4 conn.execute(sql)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\util\deprecations.py:402, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     400 if not skip_warning:
#     401     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 402 return fn(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3176, in Engine.execute(self, statement, *multiparams, **params)
#    3158 """Executes the given construct and returns a
#    3159 :class:`_engine.CursorResult`.
#    3160
#    (...)
#    3173
#    3174 """
#    3175 connection = self.connect(close_with_result=True)
# -> 3176 return connection.execute(statement, *multiparams, **params)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1291, in Connection.execute(self, statement, *multiparams, **params)
#    1282 if isinstance(statement, util.string_types):
#    1283     util.warn_deprecated_20(
#    1284         "Passing a string to Connection.execute() is "
#    1285         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1288         "driver-level SQL string."
#    1289     )
# -> 1291     return self._exec_driver_sql(
#    1292         statement,
#    1293         multiparams,
#    1294         params,
#    1295         _EMPTY_EXECUTION_OPTS,
#    1296         future=False,
#    1297     )
#    1299 try:
#    1300     meth = statement._execute_on_connection
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1595, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1585         (
#    1586             statement,
#    1587             distilled_params,
#    (...)
#    1591             statement, distilled_parameters, execution_options
#    1592         )
#    1594 dialect = self.dialect
# -> 1595 ret = self._execute_context(
#    1596     dialect,
#    1597     dialect.execution_ctx_cls._init_statement,
#    1598     statement,
#    1599     distilled_parameters,
#    1600     execution_options,
#    1601     statement,
#    1602     distilled_parameters,
#    1603 )
#    1605 if not future:
#    1606     if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\util\compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:558, in Connection.query(self, sql, unbuffered)
#     556     sql = sql.encode(self.encoding, "surrogateescape")
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:822, in Connection._read_query_result(self, unbuffered)
#     820 else:
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#     824 if result.server_status is not None:
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1200, in MySQLResult.read(self)
#    1198 def read(self):
#    1199     try:
# -> 1200         first_packet = self.connection._read_packet()
#    1202         if first_packet.is_ok_packet():
#    1203             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:772, in Connection._read_packet(self, packet_type)
#     770     if self._result is not None and self._result.unbuffered_active is True:
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1826, "Duplicate foreign key constraint name 'FK_region_year'")
# [SQL:
# ALTER TABLE `region` ADD CONSTRAINT `FK_region_year` FOREIGN KEY (`기간`) REFERENCES Electricity_production_unit_price (`기간`);
# ]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
sql = """
ALTER TABLE `sales_revenue_by_use` ADD CONSTRAINT `FK_sales_revenue_by_use_year` FOREIGN KEY (`기간`) REFERENCES Electricity_production_unit_price (`기간`);
"""
conn.execute(sql)
